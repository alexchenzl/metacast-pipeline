# %%
import openai
import json

# Read configuration from config.json
def read_config(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)

# Read JSON data from file
def read_json_from_file(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)

# Load configuration
config = read_config('config.json')

# Configure OpenAI API key
openai.api_key = config['openai_api_key']

# Get valid keywords from config
valid_keywords = config['valid_keywords']

# Read casts from transformed_json.txt
casts = read_json_from_file('transformed_json.txt')

# Process each cast entry
for cast in casts:
    prompt = f"Does the text: \"{cast['text']}\" contain related information in the keywords: {', '.join(valid_keywords)}?'Yes' means that the text is related to the keywords. 'No' means that the text is not related to the keywords at all."
    print(prompt)
    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "Determine the relevance of the keywords in the text."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=50
    )
    print(response['choices'][0]['message']['content']+"\n--------")
    
    # Determine relevance based on model response
    relevance = "Not" if "no" in response['choices'][0]['message']['content'].lower() else "Yes"
    cast['OpenAICheckRelevant'] = relevance

# Print updated JSON
print(json.dumps(casts, indent=4))

# Write the transformed JSON to a file
with open('GptChecked.txt', 'w') as outfile:
    json.dump(casts, outfile, indent=2)
# Out:
# Does the text: "" contain related information in the keywords: farcaster, social media, ethereum, communication, emoji, crypto, artificial intelligence, music, podcast, twitter, user experience, smart wallet, onchain, spotify, running, apple, bountycaster, gaming, generative art, programming, emotion, github, investment, motivation, celebration, coinbase, decentralization, excitement, space, farcon, humor, open source, bitcoin, coffee, youtube, love, meteor, productivity, astronomy, entertainment, enthusiasm, evaluation, finance, startup, weather, weekend, base, collaboration, cooking, event, fitness, geth, openai, opinion, question, return, streaming, support, travel, appreciation, assessment, channel, conversation, design, discussion, innovation, sports, address, ama, community, elon musk, exercise, family, fun, future, hypersub, launch, literature, optimism, photography, progress, request, solana, summer, surprise, announcement, degen, entrepreneurship, explanation, expression, feedback, food, founders, frame, friends, inquiry, internet, interview, memes, mint, parenting, philosophy, power badge, product development, protocol, reminder, stock market, trading, builders, construction, cool, criticism, cybersecurity, education, examination, fashion, global consensus, inspiration, observation, religion, warpcast?'Yes' means that the text is related to the keywords. 'No' means that the text is not related to the keywords at all.
# No
# --------
# Does the text: "We've only just started building crucial long-term incentives for core contributors
#
# IMO needs another order of magnitude flowing through this holistic, credibly neutral, member-governed funding mech.
#
# (incredible work to squeeze this viz out of Dune by @cheeky-gorilla 🔥)" contain related information in the keywords: farcaster, social media, ethereum, communication, emoji, crypto, artificial intelligence, music, podcast, twitter, user experience, smart wallet, onchain, spotify, running, apple, bountycaster, gaming, generative art, programming, emotion, github, investment, motivation, celebration, coinbase, decentralization, excitement, space, farcon, humor, open source, bitcoin, coffee, youtube, love, meteor, productivity, astronomy, entertainment, enthusiasm, evaluation, finance, startup, weather, weekend, base, collaboration, cooking, event, fitness, geth, openai, opinion, question, return, streaming, support, travel, appreciation, assessment, channel, conversation, design, discussion, innovation, sports, address, ama, community, elon musk, exercise, family, fun, future, hypersub, launch, literature, optimism, photography, progress, request, solana, summer, surprise, announcement, degen, entrepreneurship, explanation, expression, feedback, food, founders, frame, friends, inquiry, internet, interview, memes, mint, parenting, philosophy, power badge, product development, protocol, reminder, stock market, trading, builders, construction, cool, criticism, cybersecurity, education, examination, fashion, global consensus, inspiration, observation, religion, warpcast?'Yes' means that the text is related to the keywords. 'No' means that the text is not related to the keywords at all.
# No
# --------
# Does the text: "New: gate a Farcaster channel based on subscribing to your Paragraph newsletter.
#
# Grow your newsletter & engage with your subscribers.
#
# Enabled by @neynar and @automod." contain related information in the keywords: farcaster, social media, ethereum, communication, emoji, crypto, artificial intelligence, music, podcast, twitter, user experience, smart wallet, onchain, spotify, running, apple, bountycaster, gaming, generative art, programming, emotion, github, investment, motivation, celebration, coinbase, decentralization, excitement, space, farcon, humor, open source, bitcoin, coffee, youtube, love, meteor, productivity, astronomy, entertainment, enthusiasm, evaluation, finance, startup, weather, weekend, base, collaboration, cooking, event, fitness, geth, openai, opinion, question, return, streaming, support, travel, appreciation, assessment, channel, conversation, design, discussion, innovation, sports, address, ama, community, elon musk, exercise, family, fun, future, hypersub, launch, literature, optimism, photography, progress, request, solana, summer, surprise, announcement, degen, entrepreneurship, explanation, expression, feedback, food, founders, frame, friends, inquiry, internet, interview, memes, mint, parenting, philosophy, power badge, product development, protocol, reminder, stock market, trading, builders, construction, cool, criticism, cybersecurity, education, examination, fashion, global consensus, inspiration, observation, religion, warpcast?'Yes' means that the text is related to the keywords. 'No' means that the text is not related to the keywords at all.
# Yes
# --------
# Does the text: "I'm experimenting with Claude Sonnet 3.5 today. We're making Flappy Bird NFT: Play Flappy Bird with any NFT from your collection.
#
# So far the biggest hurdles have been getting webpack to work correctly and having the pipes emanate from the top and bottom edge of the screen — the latter seems to be introduced by the pixel dimensions of the pipe.png asset that it asked me to find online, which it does not properly account for.
#
# After a few rounds of chiding we got webpack working ok but wow these pipes don't want to pipe!" contain related information in the keywords: farcaster, social media, ethereum, communication, emoji, crypto, artificial intelligence, music, podcast, twitter, user experience, smart wallet, onchain, spotify, running, apple, bountycaster, gaming, generative art, programming, emotion, github, investment, motivation, celebration, coinbase, decentralization, excitement, space, farcon, humor, open source, bitcoin, coffee, youtube, love, meteor, productivity, astronomy, entertainment, enthusiasm, evaluation, finance, startup, weather, weekend, base, collaboration, cooking, event, fitness, geth, openai, opinion, question, return, streaming, support, travel, appreciation, assessment, channel, conversation, design, discussion, innovation, sports, address, ama, community, elon musk, exercise, family, fun, future, hypersub, launch, literature, optimism, photography, progress, request, solana, summer, surprise, announcement, degen, entrepreneurship, explanation, expression, feedback, food, founders, frame, friends, inquiry, internet, interview, memes, mint, parenting, philosophy, power badge, product development, protocol, reminder, stock market, trading, builders, construction, cool, criticism, cybersecurity, education, examination, fashion, global consensus, inspiration, observation, religion, warpcast?'Yes' means that the text is related to the keywords. 'No' means that the text is not related to the keywords at all.
# Yes
# --------
# Does the text: "something is coming…" contain related information in the keywords: farcaster, social media, ethereum, communication, emoji, crypto, artificial intelligence, music, podcast, twitter, user experience, smart wallet, onchain, spotify, running, apple, bountycaster, gaming, generative art, programming, emotion, github, investment, motivation, celebration, coinbase, decentralization, excitement, space, farcon, humor, open source, bitcoin, coffee, youtube, love, meteor, productivity, astronomy, entertainment, enthusiasm, evaluation, finance, startup, weather, weekend, base, collaboration, cooking, event, fitness, geth, openai, opinion, question, return, streaming, support, travel, appreciation, assessment, channel, conversation, design, discussion, innovation, sports, address, ama, community, elon musk, exercise, family, fun, future, hypersub, launch, literature, optimism, photography, progress, request, solana, summer, surprise, announcement, degen, entrepreneurship, explanation, expression, feedback, food, founders, frame, friends, inquiry, internet, interview, memes, mint, parenting, philosophy, power badge, product development, protocol, reminder, stock market, trading, builders, construction, cool, criticism, cybersecurity, education, examination, fashion, global consensus, inspiration, observation, religion, warpcast?'Yes' means that the text is related to the keywords. 'No' means that the text is not related to the keywords at all.
# No
# --------
# Does the text: "1/ Deeper Dive into my Long Form Post/Cast on why
#
# I’m more bullish than I have ever been about crypto.
#
# https://x.com/jerallaire/status/1803432989113593890
#
# “Public blockchain infrastructure has evolved into its 3rd generation, providing global scale network computers that can handle large scale applications with trusted data, transactions and compute.”
#
# My mental model for blockchain networks has always been network operating systems.  This is one of the most important things to help people understand what’s happening with this new infrastructure layer on the internet.
#
# The way that most “important people” (e.g. MSM, policymakers, people running big financial institutions) filter the concept of “blockchain” is typically hyper narrow – it’s a technology for “cryptocurrency”, which is “mostly bad and useless”, and even as a technology its never been proven to be useful for anything other than constructing online casinos and proliferating scams." contain related information in the keywords: farcaster, social media, ethereum, communication, emoji, crypto, artificial intelligence, music, podcast, twitter, user experience, smart wallet, onchain, spotify, running, apple, bountycaster, gaming, generative art, programming, emotion, github, investment, motivation, celebration, coinbase, decentralization, excitement, space, farcon, humor, open source, bitcoin, coffee, youtube, love, meteor, productivity, astronomy, entertainment, enthusiasm, evaluation, finance, startup, weather, weekend, base, collaboration, cooking, event, fitness, geth, openai, opinion, question, return, streaming, support, travel, appreciation, assessment, channel, conversation, design, discussion, innovation, sports, address, ama, community, elon musk, exercise, family, fun, future, hypersub, launch, literature, optimism, photography, progress, request, solana, summer, surprise, announcement, degen, entrepreneurship, explanation, expression, feedback, food, founders, frame, friends, inquiry, internet, interview, memes, mint, parenting, philosophy, power badge, product development, protocol, reminder, stock market, trading, builders, construction, cool, criticism, cybersecurity, education, examination, fashion, global consensus, inspiration, observation, religion, warpcast?'Yes' means that the text is related to the keywords. 'No' means that the text is not related to the keywords at all.
# Yes
# --------
# [
#     {
#         "hash": "0x5a169c29d4f290d6ea32491b151cf325f26c55d8",
#         "username": "six",
#         "fid": "7143",
#         "text": "",
#         "channel": "First Draft Club",
#         "likes": 183,
#         "recasts": 31,
#         "replies": 26,
#         "scv": 14022.125017800796,
#         "tags": "First Draft Club",
#         "casted_at": "2024-06-24T12:57:04Z",
#         "OpenAICheckRelevant": "Not"
#     },
#     {
#         "hash": "0xeb35abf561c42ecc85f394255bda9bdc2ea5a2bb",
#         "username": "trent",
#         "fid": "1766",
#         "text": "We've only just started building crucial long-term incentives for core contributors\n\nIMO needs another order of magnitude flowing through this holistic, credibly neutral, member-governed funding mech.\n\n(incredible work to squeeze this viz out of Dune by @cheeky-gorilla \ud83d\udd25)",
#         "channel": null,
#         "likes": 260,
#         "recasts": 59,
#         "replies": 13,
#         "scv": 12476.23782119916,
#         "tags": null,
#         "casted_at": "2024-06-24T18:53:47Z",
#         "OpenAICheckRelevant": "Not"
#     },
#     {
#         "hash": "0xbed72dc9a5457439227daf7e66d7962e073451b7",
#         "username": "colinarms.eth",
#         "fid": "378",
#         "text": "New: gate a Farcaster channel based on subscribing to your Paragraph newsletter.\n\nGrow your newsletter & engage with your subscribers.\n\nEnabled by @neynar and @automod.",
#         "channel": "Paragraph",
#         "likes": 70,
#         "recasts": 10,
#         "replies": 13,
#         "scv": 10308.89193096426,
#         "tags": "Paragraph",
#         "casted_at": "2024-06-24T14:15:54Z",
#         "OpenAICheckRelevant": "Yes"
#     },
#     {
#         "hash": "0x3a4cde3a43099db77a0ce528d5e9a49f1cbfe77a",
#         "username": "nicholas",
#         "fid": "1237",
#         "text": "I'm experimenting with Claude Sonnet 3.5 today. We're making Flappy Bird NFT: Play Flappy Bird with any NFT from your collection. \n\nSo far the biggest hurdles have been getting webpack to work correctly and having the pipes emanate from the top and bottom edge of the screen \u2014 the latter seems to be introduced by the pixel dimensions of the pipe.png asset that it asked me to find online, which it does not properly account for. \n\nAfter a few rounds of chiding we got webpack working ok but wow these pipes don't want to pipe!",
#         "channel": "AI",
#         "likes": 27,
#         "recasts": 5,
#         "replies": 7,
#         "scv": 10280.62865252667,
#         "tags": "AI",
#         "casted_at": "2024-06-24T20:44:25Z",
#         "OpenAICheckRelevant": "Yes"
#     },
#     {
#         "hash": "0xdec0485ba881858b12a3b44c59d3306c9acbd991",
#         "username": "mleejr",
#         "fid": "18085",
#         "text": "something is coming\u2026",
#         "channel": "mfers",
#         "likes": 75,
#         "recasts": 26,
#         "replies": 26,
#         "scv": 9693.09869754741,
#         "tags": "mfers",
#         "casted_at": "2024-06-24T15:29:57Z",
#         "OpenAICheckRelevant": "Not"
#     },
#     {
#         "hash": "0x4bb586e74543133242b22f1c46d31854cb564114",
#         "username": "jerallaire",
#         "fid": "238988",
#         "text": "1/ Deeper Dive into my Long Form Post/Cast on why\n\nI\u2019m more bullish than I have ever been about crypto.\n\nhttps://x.com/jerallaire/status/1803432989113593890\n\n\u201cPublic blockchain infrastructure has evolved into its 3rd generation, providing global scale network computers that can handle large scale applications with trusted data, transactions and compute.\u201d\n\nMy mental model for blockchain networks has always been network operating systems.  This is one of the most important things to help people understand what\u2019s happening with this new infrastructure layer on the internet.\n\nThe way that most \u201cimportant people\u201d (e.g. MSM, policymakers, people running big financial institutions) filter the concept of \u201cblockchain\u201d is typically hyper narrow \u2013 it\u2019s a technology for \u201ccryptocurrency\u201d, which is \u201cmostly bad and useless\u201d, and even as a technology its never been proven to be useful for anything other than constructing online casinos and proliferating scams.",
#         "channel": "Base",
#         "likes": 125,
#         "recasts": 20,
#         "replies": 11,
#         "scv": 9659.063382545175,
#         "tags": "Base",
#         "casted_at": "2024-06-24T14:31:18Z",
#         "OpenAICheckRelevant": "Yes"
#     }
# ]
